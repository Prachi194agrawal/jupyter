# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('http://bit.ly/deeplearning.mpllstyle')
# Out:
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 1 ('<!DOCTYPE html>')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 2 ('<html class="no-js" lang="en-US"> ')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 3 ('<head>')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 4 ('<meta charset="utf-8">')
# Duplicate key in file 'http://bit.ly/deeplearning.mpllstyle', line 6 ('<link rel="preload" href="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/themes/JointsWP-CSS-master/assets/scripts/jquery.min.js" as="script">')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 9 ('<meta http-equiv="X-UA-Compatible" content="IE=edge">')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 10 ('<meta name="viewport" content="width=device-width, initial-scale=1.0">')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 11 ('<meta class="foundation-mq">')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 12 ('<title>Custom Domain by Bitly</title>')
# Duplicate key in file 'http://bit.ly/deeplearning.mpllstyle', line 14 ('<meta property="og:type" content="article">')
# Duplicate key in file 'http://bit.ly/deeplearning.mpllstyle', line 15 ('<meta property="og:title" content="Custom Domain by Bitly">')
# Duplicate key in file 'http://bit.ly/deeplearning.mpllstyle', line 16 ('<meta property="og:url" content="https://bitly.com/pages/landing/branded-short-domains-powered-by-bitly">')
# Duplicate key in file 'http://bit.ly/deeplearning.mpllstyle', line 17 ('<meta property="og:site_name" content="Bitly">')
# Duplicate key in file 'http://bit.ly/deeplearning.mpllstyle', line 19 ('<meta property="article:modified_time" content="2021-10-28T18:13:26+00:00">')
# Duplicate key in file 'http://bit.ly/deeplearning.mpllstyle', line 20 ('<meta property="og:image" content="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/uploads/2023/10/homepage-default-social.png">')
# Duplicate key in file 'http://bit.ly/deeplearning.mpllstyle', line 21 ('<meta property="og:image:width" content="1200">')
# Duplicate key in file 'http://bit.ly/deeplearning.mpllstyle', line 22 ('<meta property="og:image:height" content="631">')
# Duplicate key in file 'http://bit.ly/deeplearning.mpllstyle', line 23 ('<meta property="og:image:type" content="image/png">')
# Duplicate key in file 'http://bit.ly/deeplearning.mpllstyle', line 25 ('<meta name="twitter:site" content="@Bitly">')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 28 ('<meta name="google-site-verification" content="VxdtAjqaA6XhwRJO86fcIZtRDqJAzUqlgS8AwZHmd3o">')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 29 ('<meta name="google-site-verification" content="v0y6aY7uUXw-qQm9w0YTh4VBwOMfELJ-YKG7pCd5RoQ">')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 37 ('<script>\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 38 ('(function() {\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 39 ("var a = 'bitly';\r")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 40 ("var b = '.com';\r")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 41 ('var h=window.location.hostname;\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 42 ('var i = "";\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 43 ('if(!h.includes(a+b)) {i="-test"}\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 45 ("var mainScriptAttr = '26c7d0bf-48ec-4646-8f57-e4e1135d9d05'+i;\r")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 46 ("var bl = document.createElement('script');\r")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 47 ("bl.type = 'text/javascript';\r")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 48 ('bl.src = blocker;\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 49 ("var mt = document.createElement('script');\r")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 50 ("mt.type = 'text/javascript';\r")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 52 ("mt.setAttribute('data-domain-script', mainScriptAttr); \r")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 53 ('document.head.prepend(mt);\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 54 ('//document.head.prepend(bl);\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 55 ('})();\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 56 ('</script>')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 57 ('<script id="optimizelyscript">var a=1;</script>')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 66 ("})(window,document,'script','dataLayer','GTM-MWZVBR2');</script>")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 67 ('<script>\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 68 ('setTimeout(function(){\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 69 ('if(typeof snowplow != "function"){\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 70 (';(function(p,l,o,w,i,n,g){if(!p[i]){p.GlobalSnowplowNamespace=p.GlobalSnowplowNamespace||[];\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 71 ('p.GlobalSnowplowNamespace.push(i);p[i]=function(){(p[i].q=p[i].q||[]).push(arguments)\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 72 ("};p[i].q=p[i].q||[];n=l.createElement(o);g=l.getElementsByTagName(o)[0];n.async=1;n.class='optanon-category-C0001';\r")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 74 ("snowplow('newTracker', 'sp', 'sp.bitly.com', {\r")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 83 ('}\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 84 ('});\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 85 ("snowplow('trackPageView');\r")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 86 ('} \r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 87 ('}, 2000);\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 88 ('</script>')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 89 ('</head>')
# Duplicate key in file 'http://bit.ly/deeplearning.mpllstyle', line 91 ('<script src="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/themes/JointsWP-CSS-master/assets/scripts/back.min.js" id="back-js-js"></script>')
# Duplicate key in file 'http://bit.ly/deeplearning.mpllstyle', line 92 ('<script src="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/themes/JointsWP-CSS-master/assets/scripts/infotrust.js" id="infotrust-js"></script>')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 93 ('<script id="profitwell-js" data-pw-auth="36daba674ba5cfc0ff20888a386b766b" type="text/plain" class="optanon-category-C0002">\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 94 ('/* DO NOT DELETE - this code is used to accept our payments or send data to ProfitWell   */\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 95 ('(function(i,s,o,g,r,a,m){i[o]=i[o]||function(){(i[o].q=i[o].q||[]).push(arguments)};\r')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 96 ("a=s.createElement(g);m=s.getElementsByTagName(g)[0];a.async=1;a.src=r+'?auth='+\r")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 97 ("s.getElementById(o+'-js').getAttribute('data-pw-auth');m.parentNode.insertBefore(a,m);\r")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 99 ("profitwell('start', {});\r")
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 100 ('</script>')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 101 ('<div class="icon-bag"></div> ')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 103 ('<script type="text/plain" class="optanon-category-C0002" id="hs-script-loader" async defer src="//js-eu1.hs-scripts.com/26740822.js"></script>')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 105 ('</body> ')
# Missing colon in file 'http://bit.ly/deeplearning.mpllstyle', line 106 ('</html>')
#
# Bad key <link rel="preload" href="https in file http://bit.ly/deeplearning.mpllstyle, line 6 ('<link rel="preload" href="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/themes/JointsWP-CSS-master/assets/scripts/jquery.min.js" as="script">')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <script data-cfasync="false">if(navigator.userAgent.match(/MSIE|Internet Explorer/i)||navigator.userAgent.match(/Trident\/7\..*?rv in file http://bit.ly/deeplearning.mpllstyle, line 7 ('<script data-cfasync="false">if(navigator.userAgent.match(/MSIE|Internet Explorer/i)||navigator.userAgent.match(/Trident\\/7\\..*?rv:11/i)){var href=document.location.href;if(!href.match(/[?&]iebrowser/)){if(href.indexOf("?")==-1){if(href.indexOf("#")==-1){document.location.href=href+"?iebrowser=1"}else{document.location.href=href.replace("#","?iebrowser=1#")}}else{if(href.indexOf("#")==-1){document.location.href=href+"&iebrowser=1"}else{document.location.href=href.replace("#","&iebrowser=1#")}}}}</script>')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <script data-cfasync="false">class FVMLoader{constructor(e){this.triggerEvents=e,this.eventOptions={passive in file http://bit.ly/deeplearning.mpllstyle, line 8 ('<script data-cfasync="false">class FVMLoader{constructor(e){this.triggerEvents=e,this.eventOptions={passive:!0},this.userEventListener=this.triggerListener.bind(this),this.delayedScripts={normal:[],async:[],defer:[]},this.allJQueries=[]}_addUserInteractionListener(e){this.triggerEvents.forEach(t=>window.addEventListener(t,e.userEventListener,e.eventOptions))}_removeUserInteractionListener(e){this.triggerEvents.forEach(t=>window.removeEventListener(t,e.userEventListener,e.eventOptions))}triggerListener(){this._removeUserInteractionListener(this),"loading"===document.readyState?document.addEventListener("DOMContentLoaded",this._loadEverythingNow.bind(this)):this._loadEverythingNow()}async _loadEverythingNow(){this._runAllDelayedCSS(),this._delayEventListeners(),this._delayJQueryReady(this),this._handleDocumentWrite(),this._registerAllDelayedScripts(),await this._loadScriptsFromList(this.delayedScripts.normal),await this._loadScriptsFromList(this.delayedScripts.defer),await this._loadScriptsFromList(this.delayedScripts.async),await this._triggerDOMContentLoaded(),await this._triggerWindowLoad(),window.dispatchEvent(new Event("wpr-allScriptsLoaded"))}_registerAllDelayedScripts(){document.querySelectorAll("script[type=fvmdelay]").forEach(e=>{e.hasAttribute("src")?e.hasAttribute("async")&&!1!==e.async?this.delayedScripts.async.push(e):e.hasAttribute("defer")&&!1!==e.defer||"module"===e.getAttribute("data-type")?this.delayedScripts.defer.push(e):this.delayedScripts.normal.push(e):this.delayedScripts.normal.push(e)})}_runAllDelayedCSS(){document.querySelectorAll("link[rel=fvmdelay]").forEach(e=>{e.setAttribute("rel","stylesheet")})}async _transformScript(e){return await this._requestAnimFrame(),new Promise(t=>{const n=document.createElement("script");let r;[...e.attributes].forEach(e=>{let t=e.nodeName;"type"!==t&&("data-type"===t&&(t="type",r=e.nodeValue),n.setAttribute(t,e.nodeValue))}),e.hasAttribute("src")?(n.addEventListener("load",t),n.addEventListener("error",t)):(n.text=e.text,t()),e.parentNode.replaceChild(n,e)})}async _loadScriptsFromList(e){const t=e.shift();return t?(await this._transformScript(t),this._loadScriptsFromList(e)):Promise.resolve()}_delayEventListeners(){let e={};function t(t,n){!function(t){function n(n){return e[t].eventsToRewrite.indexOf(n)>=0?"wpr-"+n:n}e[t]||(e[t]={originalFunctions:{add:t.addEventListener,remove:t.removeEventListener},eventsToRewrite:[]},t.addEventListener=function(){arguments[0]=n(arguments[0]),e[t].originalFunctions.add.apply(t,arguments)},t.removeEventListener=function(){arguments[0]=n(arguments[0]),e[t].originalFunctions.remove.apply(t,arguments)})}(t),e[t].eventsToRewrite.push(n)}function n(e,t){let n=e[t];Object.defineProperty(e,t,{get:()=>n||function(){},set(r){e["wpr"+t]=n=r}})}t(document,"DOMContentLoaded"),t(window,"DOMContentLoaded"),t(window,"load"),t(window,"pageshow"),t(document,"readystatechange"),n(document,"onreadystatechange"),n(window,"onload"),n(window,"onpageshow")}_delayJQueryReady(e){let t=window.jQuery;Object.defineProperty(window,"jQuery",{get:()=>t,set(n){if(n&&n.fn&&!e.allJQueries.includes(n)){n.fn.ready=n.fn.init.prototype.ready=function(t){e.domReadyFired?t.bind(document)(n):document.addEventListener("DOMContentLoaded2",()=>t.bind(document)(n))};const t=n.fn.on;n.fn.on=n.fn.init.prototype.on=function(){if(this[0]===window){function e(e){return e.split(" ").map(e=>"load"===e||0===e.indexOf("load.")?"wpr-jquery-load":e).join(" ")}"string"==typeof arguments[0]||arguments[0]instanceof String?arguments[0]=e(arguments[0]):"object"==typeof arguments[0]&&Object.keys(arguments[0]).forEach(t=>{delete Object.assign(arguments[0],{[e(t)]:arguments[0][t]})[t]})}return t.apply(this,arguments),this},e.allJQueries.push(n)}t=n}})}async _triggerDOMContentLoaded(){this.domReadyFired=!0,await this._requestAnimFr ...
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <meta property="og in file http://bit.ly/deeplearning.mpllstyle, line 23 ('<meta property="og:image:type" content="image/png">')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <meta property="article in file http://bit.ly/deeplearning.mpllstyle, line 19 ('<meta property="article:modified_time" content="2021-10-28T18:13:26+00:00">')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <meta name="twitter in file http://bit.ly/deeplearning.mpllstyle, line 25 ('<meta name="twitter:site" content="@Bitly">')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <script type="application/ld+json" class="yoast-schema-graph">{"@context" in file http://bit.ly/deeplearning.mpllstyle, line 26 ('<script type="application/ld+json" class="yoast-schema-graph">{"@context":"https://schema.org","@graph":[{"@type":"WebPage","@id":"https://bitly.com/pages/landing/branded-short-domains-powered-by-bitly","url":"https://bitly.com/pages/landing/branded-short-domains-powered-by-bitly","name":"Custom Domain by Bitly","isPartOf":{"@id":"https://bitly.com/pages/#website"},"datePublished":"2019-04-23T18:55:35+00:00","dateModified":"2021-10-28T18:13:26+00:00","breadcrumb":{"@id":"https://bitly.com/pages/landing/branded-short-domains-powered-by-bitly#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://bitly.com/pages/landing/branded-short-domains-powered-by-bitly"]}]},{"@type":"BreadcrumbList","@id":"https://bitly.com/pages/landing/branded-short-domains-powered-by-bitly#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Home","item":"https://bitly.com/pages/"},{"@type":"ListItem","position":2,"name":"Landing Pages","item":"https://bitly.com/pages/landing"},{"@type":"ListItem","position":3,"name":"Custom BSD Landing Page"}]},{"@type":"WebSite","@id":"https://bitly.com/pages/#website","url":"https://bitly.com/pages/","name":"Bitly","description":"Harness the click","publisher":{"@id":"https://bitly.com/pages/#organization"},"potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://bitly.com/pages/?s={search_term_string}"},"query-input":"required name=search_term_string"}],"inLanguage":"en-US"},{"@type":"Organization","@id":"https://bitly.com/pages/#organization","name":"Bitly, Inc.","url":"https://bitly.com/pages/","logo":{"@type":"ImageObject","inLanguage":"en-US","@id":"https://bitly.com/pages/#/schema/logo/image/","url":"https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/uploads/2019/02/cropped-Logo_orange1.png","contentUrl":"https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/uploads/2019/02/cropped-Logo_orange1.png","width":310,"height":152,"caption":"Bitly, Inc."},"image":{"@id":"https://bitly.com/pages/#/schema/logo/image/"},"sameAs":["https://www.facebook.com/bitly","https://twitter.com/Bitly","https://www.instagram.com/bitly/","https://www.linkedin.com/company/bitly/","https://www.youtube.com/channel/UCXqBik7fDW6jzp9PBXwiIQQ","https://en.wikipedia.org/wiki/Bitly"]}]}</script>')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
# Bad key <link rel="canonical" href="https in file http://bit.ly/deeplearning.mpllstyle, line 27 ('<link rel="canonical" href="https://bitly.com/pages/landing/branded-short-domains-powered-by-bitly">')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <link rel="preload" fetchpriority="low" id="fvmfonts-css" href="https in file http://bit.ly/deeplearning.mpllstyle, line 30 ('<link rel="preload" fetchpriority="low" id="fvmfonts-css" href="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/cache/fvm/min/1704916484-css8332866ecbbb3c1f29b2c53016cf8fff35a064ae753d5847f8c47ca625f4b.css" as="style" media="all" onload="this.rel=\'stylesheet\';this.onload=null"> ')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <link rel="stylesheet" href="https in file http://bit.ly/deeplearning.mpllstyle, line 31 ('<link rel="stylesheet" href="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/cache/fvm/min/1704916484-css88d68694317e5dd3536e9cf570f56011335a06a5cda509ec0aabdffd1f47b.css" media="all">')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <script data-cfasync="false" src="https in file http://bit.ly/deeplearning.mpllstyle, line 32 ('<script data-cfasync="false" src="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/themes/JointsWP-CSS-master/assets/scripts/jquery.min.js"></script>')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <script defer src="https in file http://bit.ly/deeplearning.mpllstyle, line 33 ('<script defer src="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/cache/fvm/min/1704916484-js7b1c93e6e3749b7fc58f8babbdfdce4baac65c2fdfdb728ece88317394c310.js"></script>')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <link rel="icon" href="https in file http://bit.ly/deeplearning.mpllstyle, line 34 ('<link rel="icon" href="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/uploads/2019/02/favicon.ico"> ')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <link rel="stylesheet" id="onetrust-css" href="https in file http://bit.ly/deeplearning.mpllstyle, line 35 ('<link rel="stylesheet" id="onetrust-css" href="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/themes/JointsWP-CSS-master/assets/styles/onetrust.css" type="text/css" media="all"> ')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <script src="https in file http://bit.ly/deeplearning.mpllstyle, line 92 ('<script src="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/themes/JointsWP-CSS-master/assets/scripts/infotrust.js" id="infotrust-js"></script>')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key var blocker = 'https in file http://bit.ly/deeplearning.mpllstyle, line 44 ("var blocker = 'https://cdn.cookielaw.org/consent/26c7d0bf-48ec-4646-8f57-e4e1135d9d05'+i+'/OtAutoBlock.js';\r")
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key mt.src = 'https in file http://bit.ly/deeplearning.mpllstyle, line 51 ("mt.src = 'https://cdn.cookielaw.org/scripttemplates/otSDKStub.js';\r")
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <style id="safe-svg-svg-icon-style-inline-css" type="text/css" media="all">.safe-svg-cover{text-align in file http://bit.ly/deeplearning.mpllstyle, line 58 ('<style id="safe-svg-svg-icon-style-inline-css" type="text/css" media="all">.safe-svg-cover{text-align:center}.safe-svg-cover .safe-svg-inside{display:inline-block;max-width:100%}.safe-svg-cover svg{height:100%;max-height:100%;max-width:100%;width:100%}</style> ')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <style id="classic-theme-styles-inline-css" type="text/css" media="all">/*! This file is auto-generated */ .wp-block-button__link{color in file http://bit.ly/deeplearning.mpllstyle, line 59 ('<style id="classic-theme-styles-inline-css" type="text/css" media="all">/*! This file is auto-generated */ .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}</style> ')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <style type="text/css" id="wp-custom-css" media="all">@media all and (min-width in file http://bit.ly/deeplearning.mpllstyle, line 60 ('<style type="text/css" id="wp-custom-css" media="all">@media all and (min-width:1024px){.plan-names.is-stuck,.pricing-row.is-stuck{z-index:200001}}@media (max-width:599px){body .content section.free-hook-block.rounded{padding-top:40px}body .content section.free-hook-block.no-padding-top{padding-top:40px}}@media all and (max-width:1099px){.hero-content{background-position:bottom right}}@media all and (max-width:1023px){section.comparison-tables table tr.pricing-row a{width:auto}section.pricing-tables.version-v2 .plan-column .plan-cta{text-align:left}section.pricing-tables .plan-column .plan-cta a.button{width:auto}#stickytable .pricing-row.sticky>td:first-child{color:#828387;font-weight:400}section.comparison-tables table tbody tr.pricing-row>td:first-child{font-weight:400}}@media all and (max-width:400px){section.pricing-tables .plan-column .plan-cta a.button{width:100%}}.home .entry-content>.cards-block:first-child{padding:30px 0;margin-bottom:40px}#sidemenu.menu .button{position:relative;padding:0}#sidemenu.menu .button a,#sidemenu.menu .button a:hover{color:white!important;padding:.7rem 1rem}.home .entry-content>.cards-block:first-child .card h5,.home .entry-content>.cards-block:first-child .card .card-image{display:none}.home .entry-content>.cards-block:first-child .card{background:transparent;border:0;margin:0}.home .entry-content>.cards-block:first-child .card p{margin:0;color:#fff}.home .entry-content>.cards-block:first-child .card .card-section{padding:0;display:flex;justify-content:center;align-items:center}.home .entry-content>.cards-block:first-child .inner-content>.cell{width:46%}.home .entry-content>.cards-block:first-child .inner-content>.cell:first-child{width:30%;padding-left:0}.home .entry-content>.cards-block:first-child .inner-content>.cell:last-child{width:15%;padding-right:0}.home .entry-content>.cards-block:first-child .inner-content>.cell:last-child .card-section{justify-content:flex-end}.home .entry-content>.cards-block:first-child{padding:30px 0}@media all and (max-width:1023px){.home .entry-content>.cards-block:first-child .inner-content>.cell:last-child{display:none}.home .entry-content>.cards-block:first-child .inner-content>.cell{width:50%}.home .entry-content>.cards-block:first-child .inner-content>.cell:first-child{width:40%}}@media all and (max-width:767px){.home .entry-content>.cards-block:first-child .inner-content>.cell:first-child{display:none}.home .entry-content>.cards-block:first-child .inner-content>.cell{width:100%;padding:0 30px}}section.press-releases>.grid-container>.grid-x{display:none}section.press-releases{padding-top:2rem}section.testimonial-block .header-m{max-width:80%;margin:0 auto}.resource-content blockquote{border:0;color:#2A2E30;font-family:\'ProximaNova ExtraBold\',\'Helvetica Neue\',Helvetica,Arial,sans-serif!important;font-size:32px;font-weight:800;letter-spacing:0;line-height:32px;padding:0;margin:30px 0}@media all and (min-width:1100px){.resource-content blockquote{margin-left:-10%;margin-right:-10%;padding:0 5%;padding-right:1%}}.resource-content blockquote p{color:#2A2E30;line-height:35px}@media all and (max-width:767px){section.testimonial-block .testimonials .testimonial-content p{margin:0;line-height:39px;font-size:20px;line-height:23px}.home .hero-content h2+p a.button-large{margin-top:5px}}ul.gallery{list-style:none!important}.page section.accordion-block .accordion-item .accordion-title::before{color:#777}section.comparison-tables table tr.pricing-row span strong{text-align:center;width:100%}@media all and (max-width:1023px){section.comparison-tables table tr.pricing-row span strong{text-align:right;width:100%;padding-right:5px}}.hide-site{display:none}.home .hide-home{display:none}.home .hide-site{display:block}.page-template-landing-pages-promo .menu-icon{display:none}.show-on-pricing{display:none}.page-pricing .show ...
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
# Bad key <style media="all">.announcements{display in file http://bit.ly/deeplearning.mpllstyle, line 61 ('<style media="all">.announcements{display:none}.home .announcements{display:block}.page-home .announcements{display:block}.page-cp .announcements{display:block}.announcements{color:#000;background-color:#CEDAFA;padding:10px 0;font-family:\'ProximaNova Medium\',\'Helvetica Neue\',Helvetica,Arial,sans-serif}.announcements p{margin:0}.announcements a{color:#000;text-decoration:underline}@media all and (max-width:767px){.announcements img{display:block;margin-left:auto;margin-right:auto}}.owl-nav button span{color:transparent!important}.top-bar-right.show-for-small ul.menu .menu-icon::after{background-image:url(https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/themes/JointsWP-CSS-master/assets/foundation-icons/svgs/feather-icon-menu.svg)}.top-bar-right.formobile ul.menu .menu-icon::after{background-image:url(https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/themes/JointsWP-CSS-master/assets/foundation-icons/svgs/feather-icon-x.svg)}.nav-wrap-mobile{position:fixed;bottom:0}</style> ')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start' in file http://bit.ly/deeplearning.mpllstyle, line 62 ("<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':\r")
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key new Date().getTime(),event in file http://bit.ly/deeplearning.mpllstyle, line 63 ("new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],\r")
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key j=d.createElement(s),dl=l!='dataLayer'?'&l='+l in file http://bit.ly/deeplearning.mpllstyle, line 64 ("j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=\r")
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key 'https in file http://bit.ly/deeplearning.mpllstyle, line 65 ("'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);\r")
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key n.src=w;g.parentNode.insertBefore(n,g)}}(window,document,"script","https in file http://bit.ly/deeplearning.mpllstyle, line 73 ('n.src=w;g.parentNode.insertBefore(n,g)}}(window,document,"script","https://cdn.jsdelivr.net/npm/@snowplow/javascript-tracker@3.4.0/dist/sp.min.js?cl=1","snowplow"));\r')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key appId in file http://bit.ly/deeplearning.mpllstyle, line 75 ("appId: 'bitly-marketing',\r")
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key anonymousTracking in file http://bit.ly/deeplearning.mpllstyle, line 76 ('anonymousTracking: { withServerAnonymisation: true },\r')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key stateStorageStrategy in file http://bit.ly/deeplearning.mpllstyle, line 77 ('stateStorageStrategy: "none",\r')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key discoverRootDomain in file http://bit.ly/deeplearning.mpllstyle, line 78 ('discoverRootDomain: true,\r')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key cookieSameSite in file http://bit.ly/deeplearning.mpllstyle, line 79 ("cookieSameSite: 'Lax', // Recommended\r")
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key contexts in file http://bit.ly/deeplearning.mpllstyle, line 80 ('contexts: {\r')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key session in file http://bit.ly/deeplearning.mpllstyle, line 81 ('session: true,\r')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key performanceTiming in file http://bit.ly/deeplearning.mpllstyle, line 82 ('performanceTiming: true\r')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <body class="page-template page-template-landing-pages page-template-landing-pages-php page page-id-5141 page-child parent-pageid-4538 wp-custom-logo page-branded-short-domains-powered-by-bitly"> <div class="announcements"><p style="text-align in file http://bit.ly/deeplearning.mpllstyle, line 90 ('<body class="page-template page-template-landing-pages page-template-landing-pages-php page page-id-5141 page-child parent-pageid-4538 wp-custom-logo page-branded-short-domains-powered-by-bitly"> <div class="announcements"><p style="text-align: center; margin: 0;"><img decoding="async" class="alignnone size-full wp-image-11853 aligncenter" role="img" src="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/uploads/2024/01/chip-1.svg" alt="" width="222" height="20"> Easily track, manage, and analyze links and QR Codes performances in one place. <a href="https://bitly.com/pages/products/analytics">Learn more</a></p> </div> <div class="off-canvas-wrapper"> <div class="off-canvas position-right" id="off-canvas" data-off-canvas> <div class="top-bar" id="top-bar-menu-off-canvas"> <div class="top-bar-left formobile"> <div class="branding"><a href="https://bitly.com/pages"><img src="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/uploads/2021/08/bitly_logo.svg" class="" alt="Bitly" width="100" height="50"></a></div> </div> <div class="top-bar-right formobile"> <ul class="menu"> <li><button class="menu-icon" type="button" data-toggle="off-canvas">Menu</button></li> </ul> </div> </div> <ul id="offcanvas-nav" class="vertical menu accordion-menu" data-accordion-menu data-multi-open="false"><li id="menu-item-8815" class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu-item-8815"><a id="offcanvas-nav-products-2" href="#">Products</a> <ul class="vertical menu"> <li id="menu-item-11653" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-11653"><a id="offcanvas-nav-11653" href="https://bitly.com/pages/products/url-shortener" class="menu-image-title-after menu-image-not-hovered"><img width="24" height="26" src="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/uploads/2024/01/short-link-1.svg" class="menu-image menu-image-title-after" alt="" decoding="async"><span class="menu-image-title-after menu-image-title">URL Shortener</span><span class="menu-item-description">Customize, share, and track links</span></a></li> <li id="menu-item-10762" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-10762"><a id="offcanvas-nav-10762" href="https://bitly.com/pages/products/qr-codes" class="menu-image-title-after menu-image-not-hovered"><img width="24" height="26" src="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/uploads/2024/01/qr-code.svg" class="menu-image menu-image-title-after" alt="" decoding="async"><span class="menu-image-title-after menu-image-title">QR Codes</span><span class="menu-item-description">Dynamic solutions to fit every business need</span></a></li> <li id="menu-item-8818" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-8818"><a id="offcanvas-nav-link-in-bio" href="https://bitly.com/pages/products/link-in-bio" class="menu-image-title-after menu-image-not-hovered"><img width="24" height="26" src="https://docrdsfx76ssb.cloudfront.net/static/1704916843/pages/wp-content/uploads/2024/01/link-in-bio.svg" class="menu-image menu-image-title-after" alt="" decoding="async"><span class="menu-image-title-after menu-image-title">Link-in-bio</span><span class="menu-item-description">Curate and track links for social media profiles</span></a></li> <li id="menu-item-11850" class="menu-item menu-item-type-post_type menu-item-object-page menu-item-11850"><a id="offcanvas-nav-11850" href="https://bitly.com/pages/products/analytics" class="menu-image-title-after menu-image-not-hovered"><img width="24" height="26" src="https://docrdsfx76ssb.cloudfront.net/st ...
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
# Bad key })(window,document,'profitwell','script','https in file http://bit.ly/deeplearning.mpllstyle, line 98 ("})(window,document,'profitwell','script','https://public.profitwell.com/js/profitwell.js');\r")
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <noscript><iframe src="https in file http://bit.ly/deeplearning.mpllstyle, line 102 ('<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MWZVBR2" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution
#
# Bad key <script type="text/plain" class="optanon-category-C0002" async src="https in file http://bit.ly/deeplearning.mpllstyle, line 104 ('<script type="text/plain" class="optanon-category-C0002" async src="https://cdn.optimizely.com/js/16488430484.js"></script>')
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.8.0/lib/matplotlib/mpl-data/matplotlibrc
# or from the matplotlib source distribution

# %%
x_train=np.array([1.0,2.0])
y_train=np.array([300,500])

# %%
m=len(x_train)
print(f"Number of training examples is:{m}")
# Out:
# Number of training examples is:2

# %%
i=0
x_i=x_train[i]
y_i=y_train[i]
print(f"(x^({i}),y^{i}))=({x_i},{y_i}")
# Out:
# (x^(0),y^0))=(1.0,300

# %%
# plot the data points
plt.scatter(x_train,y_train,marker='x',c='r')
# set the style
plt.title("Housing Prices")
# set the y- axis label
plt.ylabel('Price (in 1000s of dollars)')
# set the x-axis label
plt.xlabel('Size(1000 sqft)')
plt.show()

# %%
w=100
b=100
print(f"w:{w}")
print(f"b:{b}")
# Out:
# w:100
# b:100

# %%
def calculate_model_output(w,b,x):
    m=x.shape
    f_wb=np.zeros(m)
    for i in range(len(x)):
        f_wb[i]=w*x[i]+b
        
    return f_wb

# %%
tmp_f_wb=calculate_model_output(w,b,x_train)

# plot our model prediction
plt.plot(x_train,tmp_f_wb,c='b',label='Our Predictions')

# plot the data point
plt.scatter(x_train,y_train,marker='x',c='r',label='Actual Values')

# set the title
plt.title("Housing Prices")
# set the y-label
plt.ylabel('Price(in 1000s of dollars)')
# set the x-axis label
plt.xlabel('Size(1000 sqft)')
plt.legend()
plt.show()

# %%
w=200
b=100
cost_1200sqft=w*1.200+b
print(f"${cost_1200sqft:0f}thousand dollars")
# Out:
# $340.000000thousand dollars
